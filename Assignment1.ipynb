# %%
student_list=["Atharv","Sahil","Abhiraj","Sumedh"]
student_tuple={"Atharv","Sahil","Abhiraj","Sumedh"}
student_dict= {
    101:"Atharv",
    102:"Sahil",
    103:"Abhiraj",
    104:"Sumedh",
}
print("Student list")
print(student_list)

print("Student tuple")
print(student_tuple)

print("Student dictionary")
print(student_dict)
# Out:
# Student list
# ['Atharv', 'Sahil', 'Abhiraj', 'Sumedh']
# Student tuple
# {'Sumedh', 'Sahil', 'Atharv', 'Abhiraj'}
# Student dictionary
# {101: 'Atharv', 102: 'Sahil', 103: 'Abhiraj', 104: 'Sumedh'}

# %%
student_dict[105]="Rohan"
print(student_dict)
# Out:
# {101: 'Atharv', 102: 'Sahil', 103: 'Abhiraj', 104: 'Sumedh', 105: 'Rohan'}

# %%
student_dict[102]="Sahil Kudi"
print(student_dict)
# Out:
# {101: 'Atharv', 102: 'Sahil Kudi', 103: 'Abhiraj', 104: 'Sumedh', 105: 'Rohan'}

# %%
del student_dic
